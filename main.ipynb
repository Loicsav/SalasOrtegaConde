# %% [markdown]
# # Práctica 1: Aprendizaje por Refuerzo
#
# **Asignatura**: Extensiones de Machine Learning, 2025/2026
#
# **Autores**:
# * Alberto Ortega Pastor
# * Manuel Salas Díaz
# * Lola Conde Herrera
#
# **Máster de Inteligencia Artificial**
#
# **Facultad de Informática**
#
# ![](https://www.um.es/image/layout_set_logo?img_id=175281&t=1726728636242)
#
# **Universidad de Murcia**
#
# ![](https://www.um.es/o/um-lr-principal-um-home-theme/images/logo-um.png)
#
# -----

# %% [markdown]
# Este notebook sirve como punto de inicio para poder preparar el entorno y moverse a los diferentes notebooks.
#
# **Pasos a realizar en cualquier notebook**
# 1. Carga el notebook en ``Colab``: [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/main.ipynb)
# 2. Ejecutar todas las celdas del notebook para clonar el repositorio.
# 3. Utilizar los enlaces de abajo para acceder a los diferentes notebooks.

# %% [markdown]
# # Clonar el Repositorio GitHub

# %%
# Clonar el repositorio en Google Colab
# !git clone https://github.com/Loicsav/SalasOrtegaConde.git
# %cd SalasOrtegaConde

# Confirmar clonación exitosa
print("✅ Repositorio clonado con éxito.")

# %% [markdown]
# ## Acceso a los Notebooks del Proyecto
#
# ### K-Brazos
# - [Greedy - Estudio comparativo de algoritmos ε-greedy en un problema de k-armed bandit](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/k-brazos/Greedy.ipynb)
#
# - [UCB - Estudio comparativo de algoritmos UCB en un problema de k-armed bandit](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/k-brazos/UCB.ipynb)
#
# - [Algoritmo Softmax - Estudio comparativo de algoritmos softmax en un problema de k-armed bandit](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/k-brazos/Softmax.ipynb)
#
# - [ComparativaAlgoritmos - Estudio comparativo de algoritmos en un problema de k-armed bandit](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/k-brazos/ComparativaAlgoritmos.ipynb)
#
#
# ### Entornos Complejos
#
# - [MonteCarloTodasLasVisitas - Estudio del algoritmo de Monte Carlo con Políticas ε-soft](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/Entornos_Complejos/MonteCarloTodasLasVisitas.ipynb)
#
# - [DiferenciaTemporales - Estudio de algoritmos tabulares en Diferencias Temporales](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/Entornos_Complejos/DiferenciaTemporal.ipynb)
#
# - [MetodosAproximados - Estudio de algoritmos en entornos aproximados](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/Entornos_Complejos/MetodosAproximados.ipynb)
#
# - [Sarsa_sg_parametros_experimentacion - Estudio de parámetros de Sarsa Semigradiente](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/Entornos_Complejos/Sarsa_sg_parametros_experimentación.ipynb)
#
# - [ComparativaGlobal - Comparativa Global de Algoritmos Tabulares y Aproximados](https://colab.research.google.com/github/Loicsav/SalasOrtegaConde/blob/main/Entornos_Complejos/ComparativaGlobal.ipynb)
